# %%
#Importing Necessary Library
import selenium
from selenium import webdriver
import pandas as pd
import time
from time import sleep
import warnings
warnings.filterwarnings("ignore")

# %%
#Installing Driver for Macbook
driver = webdriver.Chrome(r'/Users/rishabh/Desktop/chromedriver')

# %% [markdown]
# # Question.1

# %%
driver.get('http://www.amazon.in/')

# %%
input_user = input('Enter the element to be search: ')
# Out:
# Enter the element to be search: Guitar

# %%
search_bar = driver.find_element_by_id('twotabsearchtextbox')
search_bar.send_keys(input_user)

# %%
srch = driver.find_element_by_id('nav-search-submit-button')
srch.click()

# %% [markdown]
# # Question.2

# %%
url=[]
for i in driver.find_elements_by_xpath('//a[@class="a-link-normal s-link-style a-text-normal"]'):
    url.append(i.get_attribute('href'))

# %%
prod_name_ = []
rating = []
price = []
avail = []
no_rating=[]
exc=[]
brand_name=[]
color=[]
other=[]
delivery=[]

# %%
from selenium.common.exceptions import NoSuchElementException, StaleElementReferenceException
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.keys import Keys

# %%
# Running this code first time to fetch the data from first page(url)
for i in url: 
    driver.get(i)
    time.sleep(2)
    try:
        p=driver.find_element_by_id('productTitle')
        prod_name_.append(p.text.replace('/n',''))
    except NoSuchElementException:
        prod_name_.append('-')
    try:
        pr=driver.find_element_by_id('priceblock_ourprice')
        price.append(pr.text.replace('/n',''))
    except NoSuchElementException:
        price.append('-')
    try:
        r=driver.find_element_by_xpath("//span[@class='a-size-medium a-color-base']")
        rating.append(r.text.replace('/n',''))
    except NoSuchElementException:
        rating.append('-')
    try:
        r=driver.find_element_by_id("availability")
        avail.append(r.text.replace('/n',''))
    except NoSuchElementException:
        avail.append('-')
    try:
        r=driver.find_element_by_id("acrCustomerReviewText")
        no_rating.append(r.text.replace('/n',''))
    except NoSuchElementException:
        no_rating.append('-')
    try:
        r=driver.find_element_by_xpath("//table[@class='a-normal a-spacing-micro']/tbody/tr/td[2]/span")
        brand_name.append(r.text.replace('/n',''))
    except NoSuchElementException:
        brand_name.append('-')
    try:
        r=driver.find_element_by_xpath("//div[@class='a-section a-spacing-none icon-content'][1]/a")
        exc.append(r.text.replace('/n',''))
    except NoSuchElementException:
        exc.append('-')
    try:
        r=driver.find_element_by_xpath("//table[@class='a-normal a-spacing-micro']/tbody/tr[2]/td[2]/span")
        color.append(r.text.replace('/n',''))
    except NoSuchElementException:
        color.append('-')
    try:
        r=driver.find_element_by_id("productDescription")
        other.append(r.text.replace('/n',''))
    except NoSuchElementException:
        other.append('-')
    try:
        r=driver.find_element_by_xpath("//div[@class='a-section a-spacing-mini'][1]/b")
        delivery.append(r.text.replace('/n',''))
    except NoSuchElementException:
        delivery.append('-')

# %%
# After fetching the  data of first page the last product url is on the browser so again directing to first page.
srch = driver.find_element_by_id('nav-search-submit-button')
srch.click()

# %%
# Moving from first page to second page.
nxt = driver.find_element_by_xpath("//a[@class='s-pagination-item s-pagination-next s-pagination-button s-pagination-separator']")
nxt.click()

# %%
url_1=[]
for i in driver.find_elements_by_xpath('//a[@class="a-link-normal s-link-style a-text-normal"]'):
    url_1.append(i.get_attribute('href'))

# %%
# Running this code second time to fetch the data from second page(url_1)
for i in url_1: 
    driver.get(i)
    time.sleep(2)
    try:
        p=driver.find_element_by_id('productTitle')
        prod_name_.append(p.text.replace('/n',''))
    except NoSuchElementException:
        prod_name_.append('-')
    try:
        pr=driver.find_element_by_id('priceblock_ourprice')
        price.append(pr.text.replace('/n',''))
    except NoSuchElementException:
        price.append('-')
    try:
        r=driver.find_element_by_xpath("//span[@class='a-size-medium a-color-base']")
        rating.append(r.text.replace('/n',''))
    except NoSuchElementException:
        rating.append('-')
    try:
        r=driver.find_element_by_id("availability")
        avail.append(r.text.replace('/n',''))
    except NoSuchElementException:
        avail.append('-')
    try:
        r=driver.find_element_by_id("acrCustomerReviewText")
        no_rating.append(r.text.replace('/n',''))
    except NoSuchElementException:
        no_rating.append('-')
    try:
        r=driver.find_element_by_xpath("//table[@class='a-normal a-spacing-micro']/tbody/tr/td[2]/span")
        brand_name.append(r.text.replace('/n',''))
    except NoSuchElementException:
        brand_name.append('-')
    try:
        r=driver.find_element_by_xpath("//div[@class='a-section a-spacing-none icon-content'][1]/a")
        exc.append(r.text.replace('/n',''))
    except NoSuchElementException:
        exc.append('-')
    try:
        r=driver.find_element_by_xpath("//table[@class='a-normal a-spacing-micro']/tbody/tr[2]/td[2]/span")
        color.append(r.text.replace('/n',''))
    except NoSuchElementException:
        color.append('-')
    try:
        r=driver.find_element_by_id("productDescription")
        other.append(r.text.replace('/n',''))
    except NoSuchElementException:
        other.append('-')
    try:
        r=driver.find_element_by_xpath("//div[@class='a-section a-spacing-mini'][1]/b")
        delivery.append(r.text.replace('/n',''))
    except NoSuchElementException:
        delivery.append('-')

# %%
# After fetching the  data of second page the last product url is on the browser so again directing to first page.
srch = driver.find_element_by_id('nav-search-submit-button')
srch.click()

# %%
#For moving from first to third page we need to run this code twice.
nxt = driver.find_element_by_xpath("//a[@class='s-pagination-item s-pagination-next s-pagination-button s-pagination-separator']")
nxt.click()

# %%
url_2=[]
for i in driver.find_elements_by_xpath('//a[@class="a-link-normal s-link-style a-text-normal"]'):
    url_2.append(i.get_attribute('href'))

# %%
# Running this code third time to fetch the data from third page(url_2)
for i in url_2:
    driver.get(i)
    time.sleep(2)
    try:
        p=driver.find_element_by_id('productTitle')
        prod_name_.append(p.text.replace('/n',''))
    except NoSuchElementException:
        prod_name_.append('-')
    try:
        pr=driver.find_element_by_id('priceblock_ourprice')
        price.append(pr.text.replace('/n',''))
    except NoSuchElementException:
        price.append('-')
    try:
        r=driver.find_element_by_xpath("//span[@class='a-size-medium a-color-base']")
        rating.append(r.text.replace('/n',''))
    except NoSuchElementException:
        rating.append('-')
    try:
        r=driver.find_element_by_id("availability")
        avail.append(r.text.replace('/n',''))
    except NoSuchElementException:
        avail.append('-')
    try:
        r=driver.find_element_by_id("acrCustomerReviewText")
        no_rating.append(r.text.replace('/n',''))
    except NoSuchElementException:
        no_rating.append('-')
    try:
        r=driver.find_element_by_xpath("//table[@class='a-normal a-spacing-micro']/tbody/tr/td[2]/span")
        brand_name.append(r.text.replace('/n',''))
    except NoSuchElementException:
        brand_name.append('-')
    try:
        r=driver.find_element_by_xpath("//div[@class='a-section a-spacing-none icon-content'][1]/a")
        exc.append(r.text.replace('/n',''))
    except NoSuchElementException:
        exc.append('-')
    try:
        r=driver.find_element_by_xpath("//table[@class='a-normal a-spacing-micro']/tbody/tr[2]/td[2]/span")
        color.append(r.text.replace('/n',''))
    except NoSuchElementException:
        color.append('-')
    try:
        r=driver.find_element_by_id("productDescription")
        other.append(r.text.replace('/n',''))
    except NoSuchElementException:
        other.append('-')
    try:
        r=driver.find_element_by_xpath("//div[@class='a-section a-spacing-mini'][1]/b")
        delivery.append(r.text.replace('/n',''))
    except NoSuchElementException:
        delivery.append('-')

# %%
# Appending urls of second and third page to first list. 
url.extend(url_1)   
url.extend(url_2)

# %%
# Checking the length of our url.
len(url)
# Out:
# 181

# %%
#Making DataFrame
amazon_guitar = pd.DataFrame({})
amazon_guitar['Brand Name'] = brand_name
amazon_guitar['Product Name'] = prod_name_
amazon_guitar['Price'] = price
amazon_guitar['Rating'] = rating
amazon_guitar['No of ratings'] = no_rating
amazon_guitar['Delivery'] = delivery
amazon_guitar['Availability'] = avail
amazon_guitar['Exchange'] = exc
amazon_guitar['Color'] = color
amazon_guitar['Product_url'] = url

# %%
amazon_guitar
# Out:
#        Brand Name                                       Product Name Price  \
# 0        Medellin  Medellin 38" Acoustic Guitar Blue Burst Carbon...     -
# 1           VAULT  Vault EA40 Premium 41 inch Spruce-Top Cutaway ...     -
# 2           VAULT          Vault ST1 Premium Electric Guitar - White     -
# 3           VAULT  Vault ST1 Strat Style 6 String Electric Guitar...     -
# 4          Juârez  Juârez Acoustic Guitar, 38 Inch Cutaway, 038C ...     -
# ..            ...                                                ...   ...
# 176       Kadence  Kadence AstroMan Electric Guitar, 21 FRETS, RO...     -
# 177        Kramer  Kramer Baretta Special 6 strings Right Handed ...     -
# 178        Festra  Festra 38C, 38 Inch Acoustic Guitar Kit with B...     -
# 179          Cort                 Cort X100 6-String Electric Guitar     -
# 180  Martin Smith  Martin Smith W-101-N-PK Acoustic Guitar Super ...     -
#
#            Rating   No of ratings           Delivery           Availability  \
# 0    4.4 out of 5       5 ratings   Saturday, Jan 29              In stock.
# 1    3.9 out of 5     247 ratings    Tuesday, Jan 25              In stock.
# 2      4 out of 5      32 ratings    Tuesday, Jan 25  Only 2 left in stock.
# 3      4 out of 5      13 ratings    Tuesday, Jan 25              In stock.
# 4      4 out of 5  14,823 ratings    Tuesday, Jan 25              In stock.
# ..            ...             ...                ...                    ...
# 176  4.1 out of 5      36 ratings   Saturday, Jan 29              In stock.
# 177    5 out of 5       3 ratings   Thursday, Jan 27              In stock.
# 178             -               -   Thursday, Jan 27              In stock.
# 179  3.6 out of 5      18 ratings  Wednesday, Jan 26              In stock.
# 180  4.3 out of 5   3,473 ratings  Wednesday, Jan 26              In stock.
#
#             Exchange            Color  \
# 0    Pay on Delivery       Blue Burst
# 1    Pay on Delivery  Natural-41 inch
# 2    Pay on Delivery            White
# 3    Pay on Delivery            BLACK
# 4    Pay on Delivery            Black
# ..               ...              ...
# 176  Pay on Delivery         Sunburst
# 177  Pay on Delivery            Black
# 178  Pay on Delivery         Sunburst
# 179  Pay on Delivery  Open Pore Black
# 180  Pay on Delivery          Natural
#
#                                            Product_url
# 0    https://www.amazon.in/gp/slredirect/picassoRed...
# 1    https://www.amazon.in/gp/slredirect/picassoRed...
# 2    https://www.amazon.in/gp/slredirect/picassoRed...
# 3    https://www.amazon.in/gp/slredirect/picassoRed...
# 4    https://www.amazon.in/Juarez-Acoustic-Cutaway-...
# ..                                                 ...
# 176  https://www.amazon.in/Kadence-Electric-Guitar-...
# 177  https://www.amazon.in/Kramer-Baretta-Special-s...
# 178  https://www.amazon.in/Festra-Acoustic-Guitar-S...
# 179  https://www.amazon.in/Cort-X100-6-String-Elect...
# 180  https://www.amazon.in/Martin-Smith-W-101-N-PK-...
#
# [181 rows x 10 columns]

# %%
df_guitar = amazon_guitar.to_csv(index = False)

# %% [markdown]
# # Question.3

# %%
driver.get('https://images.google.com')

# %%
# Creating a function which takes the necessary input as argument
def get_urls(keywords):
        driver.get('https://images.google.com')

        # Locating the search bar and click search button
        search_bar=driver.find_element_by_xpath("//input[@class='gLFyf gsfi']")
        search_bar.send_keys(keywords)
        button=driver.find_element_by_xpath("//button[@class='Tg7LZd']")
        button.click()
        time.sleep(3)
        
        # loading few pages to scrape images
        for k in range(10):
            driver.find_element_by_xpath("//a[@class='wXeWr islib nfEiy']").send_keys(Keys.PAGE_DOWN)
        time.sleep(5)
        picture = [image for image in driver.find_elements_by_xpath("//a[@class='wXeWr islib nfEiy']")[:10]]
        image_urls=[]
        print(len(picture))
        if(len(picture)==10):
            for i in picture:
                try:
                    i.click()
                    image_urls.append(i.get_attribute('href'))
                except:
                    image_urls.append('Not Available')
            return image_urls
        else:
            print('Image Not Available')

# %%
#Let's scrape the url's of all images
fruits = get_urls('Fruits')
cars = get_urls('Cars')
machine_learning = get_urls('Machine Learning')
guitar = get_urls('Guitar')
cake = get_urls('Cakes')
# Out:
# 10
# 10
# 10
# 10
# 10

# %%
# Let's create a DataFrame for our data
Image_URL = pd.DataFrame({})
Image_URL['Fruits'] = fruits
Image_URL['Cars'] = cars
Image_URL['Machine Learning'] = machine_learning
Image_URL['Guitar'] = guitar
Image_URL['Cakes'] = cake

Image_URL
# Out:
#                                               Fruits  \
# 0  https://www.google.com/imgres?imgurl=https%3A%...
# 1  https://www.google.com/imgres?imgurl=https%3A%...
# 2  https://www.google.com/imgres?imgurl=https%3A%...
# 3  https://www.google.com/imgres?imgurl=https%3A%...
# 4  https://www.google.com/imgres?imgurl=https%3A%...
# 5  https://www.google.com/imgres?imgurl=https%3A%...
# 6  https://www.google.com/imgres?imgurl=https%3A%...
# 7  https://www.google.com/imgres?imgurl=https%3A%...
# 8  https://www.google.com/imgres?imgurl=https%3A%...
# 9  https://www.google.com/imgres?imgurl=https%3A%...
#
#                                                 Cars  \
# 0  https://www.google.com/imgres?imgurl=https%3A%...
# 1  https://www.google.com/imgres?imgurl=https%3A%...
# 2  https://www.google.com/imgres?imgurl=https%3A%...
# 3  https://www.google.com/imgres?imgurl=https%3A%...
# 4  https://www.google.com/imgres?imgurl=https%3A%...
# 5  https://www.google.com/imgres?imgurl=http%3A%2...
# 6  https://www.google.com/imgres?imgurl=https%3A%...
# 7  https://www.google.com/imgres?imgurl=https%3A%...
# 8  https://www.google.com/imgres?imgurl=https%3A%...
# 9  https://www.google.com/imgres?imgurl=https%3A%...
#
#                                     Machine Learning  \
# 0  https://www.google.com/imgres?imgurl=https%3A%...
# 1  https://www.google.com/imgres?imgurl=https%3A%...
# 2  https://www.google.com/imgres?imgurl=https%3A%...
# 3  https://www.google.com/imgres?imgurl=https%3A%...
# 4  https://www.google.com/imgres?imgurl=https%3A%...
# 5  https://www.google.com/imgres?imgurl=https%3A%...
# 6  https://www.google.com/imgres?imgurl=https%3A%...
# 7  https://www.google.com/imgres?imgurl=https%3A%...
# 8  https://www.google.com/imgres?imgurl=https%3A%...
# 9  https://www.google.com/imgres?imgurl=https%3A%...
#
#                                               Guitar  \
# 0  https://www.google.com/imgres?imgurl=https%3A%...
# 1  https://www.google.com/imgres?imgurl=https%3A%...
# 2  https://www.google.com/imgres?imgurl=https%3A%...
# 3  https://www.google.com/imgres?imgurl=https%3A%...
# 4  https://www.google.com/imgres?imgurl=https%3A%...
# 5  https://www.google.com/imgres?imgurl=https%3A%...
# 6  https://www.google.com/imgres?imgurl=https%3A%...
# 7  https://www.google.com/imgres?imgurl=https%3A%...
# 8  https://www.google.com/imgres?imgurl=https%3A%...
# 9  https://www.google.com/imgres?imgurl=https%3A%...
#
#                                                Cakes
# 0  https://www.google.com/imgres?imgurl=https%3A%...
# 1  https://www.google.com/imgres?imgurl=https%3A%...
# 2  https://www.google.com/imgres?imgurl=https%3A%...
# 3  https://www.google.com/imgres?imgurl=https%3A%...
# 4  https://www.google.com/imgres?imgurl=https%3A%...
# 5  https://www.google.com/imgres?imgurl=https%3A%...
# 6  https://www.google.com/imgres?imgurl=https%3A%...
# 7  https://www.google.com/imgres?imgurl=https%3A%...
# 8  https://www.google.com/imgres?imgurl=https%3A%...
# 9  https://www.google.com/imgres?imgurl=https%3A%...

# %% [markdown]
# # Question.4

# %%
driver.get("https://www.flipkart.com/")

# %%
#Searching the web element for input
search = driver.find_element_by_xpath('//input[@title="Search for products, brands and more"]')
search.send_keys('smartphone')

# %%
# Locating the search button using xpath
search_btn = driver.find_element_by_xpath('//button[@class="L0Z3Pu"]')

# %%
# Clicking on search button
search_btn.click()

# %%
# Creating empty lists to store the fetched data
product_urls = []
brand_name = []
smartphone_name = []
smartphone_color = []
RAM = []
ROM = []
primary_camera = []
secondary_camera = []
display_size = []
display_resolution = []
processor = []
processor_core = []
battery_capacity = []
price = []

# %%
#Let's define a function.
link = driver.find_elements_by_xpath('//a[@class="_1fQZEK"]')

# %%
#Let's scrape product URL
for i in link:
    product_urls.append(i.get_attribute('href'))
for i in product_urls:
    driver.get(i)
    driver.implicitly_wait(4)
    driver.find_element_by_xpath('//button[@class="_2KpZ6l _1FH0tX"]').click()
    try:
        
#Let's scrape brand name
        title=driver.find_element_by_xpath('//span[@class="B_NuCI"]').text.split()
        brand_name.append(title[0])
    except:
        brand_name.append('-')
    try:
        
#Let's scrape smartohone name
        smartphone_name.append(driver.find_element_by_xpath('//div[@class="_1UhVsV"]/div[1]/table/tbody/tr[3]/td[2]').text)
    except:
        smartphone_name.append('-')
    try:
        
#Let's scrape smartphone colour
        smartphone_color.append(driver.find_element_by_xpath('//div[@class="_1UhVsV"]/div[1]/table/tbody/tr[4]/td[2]').text)
    except:
        smartphone_color.append('-')
    try:
        
#Let's scrape smartphone RAM
        RAM.append(driver.find_element_by_xpath('//div[@class="_1UhVsV"]/div[4]/table/tbody/tr[2]/td[2]').text)
    except:
        RAM.append('-')
    try:
        
#Let's scrape smartphone ROM
        ROM.append(driver.find_element_by_xpath('//div[@class="_1UhVsV"]/div[4]/table/tbody/tr[1]/td[2]').text)
    except:
        ROM.append('-')
    try:
        
#Let's scrape smartphone primary camera details
        primary_camera.append(driver.find_element_by_xpath('//div[@class="_1UhVsV"]/div[5]/table/tbody/tr[2]/td[2]').text)
    except:
        primary_camera.append('-')
    try:
        
#Let's scrape smartphone secondary camera details
        secondary_camera.append(driver.find_element_by_xpath('//div[@class="_1UhVsV"]/div[5]/table/tbody/tr[5]/td[2]').text)
    except:
        secondary_camera.append('-')
    try:
        
#Let's scrape smartphone display size
        display_size.append(driver.find_element_by_xpath('//div[@class="_1UhVsV"]/div[2]/table/tbody/tr[1]/td[2]').text)
    except:
        display_size.append('-')
    try:
        
#Let's scrape smartphone screen resolution
        display_resolution.append(driver.find_element_by_xpath('//div[@class="_1UhVsV"]/div[2]/table/tbody/tr[2]/td[2]').text)
    except:
        display_resolution.append('-')
    try:
        
#Let's scrape smartphone processor
        processor.append(driver.find_element_by_xpath('//div[@class="_1UhVsV"]/div[3]/table/tbody/tr[2]/td[2]').text)
    except:
        processor.append('-')
    try:
        
#Let's scrape smartphone processor core
        processor_core.append(driver.find_element_by_xpath('//div[@class="_1UhVsV"]/div[3]/table/tbody/tr[3]/td[2]').text)
    except:
        processor_core.append('-')
    try:
        
#Let's scrape smartphone battery capacity
        battery_capacity.append(driver.find_element_by_xpath('//div[@class="_1UhVsV"]/div[10]/table/tbody/tr[1]/td[2]').text)
    except:
        battery_capacity.append('-')
    try:
        
#Let's scrape smartphone price
        price.append(driver.find_element_by_xpath('//div[@class="dyC4hf"]/div/div/div').text)
    except:
        price.append('-')

# %%
# Creating a DATA FRAME to store fetched data
Flipkart=pd.DataFrame({})
Flipkart['Brand Name'] = brand_name
Flipkart['Smartphone Name'] = smartphone_name
Flipkart['Smartphone Colour'] = smartphone_color
Flipkart['RAM'] = RAM
Flipkart['Storage (ROM)'] = ROM
Flipkart['Primray Camera'] = primary_camera
Flipkart['Secondary Camera'] = secondary_camera
Flipkart['Display Size'] = display_size
Flipkart['Display Resolution'] = display_resolution
Flipkart['Processor'] = processor
Flipkart['Processor Cores'] = processor_core
Flipkart['Battery Capacity'] = battery_capacity
Flipkart['Price'] = price
Flipkart['Product URL'] = product_urls

Flipkart
# Out:
#    Brand Name Smartphone Name Smartphone Colour   RAM Storage (ROM)  \
# 0      realme       Narzo 50i      Carbon Black  2 GB         32 GB
# 1      realme       Narzo 50i        Mint Green  2 GB         32 GB
# 2      realme       Narzo 50i      Carbon Black  4 GB         64 GB
# 3     SAMSUNG      Galaxy F12         Sea Green  4 GB         64 GB
# 4      realme       Narzo 50A       Oxygen Blue  4 GB        128 GB
# 5      realme       Narzo 50A       Oxygen Blue  4 GB         64 GB
# 6      realme       Narzo 50A      Oxygen Green  4 GB         64 GB
# 7      realme            C21Y        Cross Blue  4 GB         64 GB
# 8      realme            C21Y        Cross Blue  3 GB         32 GB
# 9      realme            C21Y       Cross Black  4 GB         64 GB
# 10     realme       Narzo 50i        Mint Green  4 GB         64 GB
# 11     realme            C25Y      Glacier Blue  4 GB        128 GB
# 12     realme            C25Y        Metal Grey  4 GB        128 GB
# 13     realme       Narzo 50A      Oxygen Green  4 GB        128 GB
# 14    SAMSUNG      Galaxy F12          Sky Blue  4 GB         64 GB
# 15     realme            C21Y       Cross Black  3 GB         32 GB
# 16    SAMSUNG      Galaxy F12   Celestial Black  4 GB         64 GB
# 17       OPPO             A12             Black  3 GB         32 GB
# 18       OPPO             A12    Flowing Silver  4 GB         64 GB
# 19     realme        C11 2021         Cool Grey  2 GB         32 GB
# 20     realme        C11 2021         Cool Blue  2 GB         32 GB
# 21     realme           C25_Y        Metal Grey  4 GB         64 GB
# 22     realme           C25_Y        Metal Grey  4 GB        128 GB
# 23     realme           C25_Y      Glacier Blue  4 GB        128 GB
#
#             Primray Camera  Secondary Camera           Display Size  \
# 0          8MP Rear Camera  5MP Front Camera    16.51 cm (6.5 inch)
# 1          8MP Rear Camera  5MP Front Camera    16.51 cm (6.5 inch)
# 2          8MP Rear Camera  5MP Front Camera    16.51 cm (6.5 inch)
# 3   48MP + 5MP + 2MP + 2MP  8MP Front Camera  16.55 cm (6.515 inch)
# 4         50MP + 2MP + 2MP  8MP Front Camera    16.51 cm (6.5 inch)
# 5         50MP + 2MP + 2MP  8MP Front Camera    16.51 cm (6.5 inch)
# 6         50MP + 2MP + 2MP  8MP Front Camera    16.51 cm (6.5 inch)
# 7         13MP + 2MP + 2MP  5MP Front Camera    16.51 cm (6.5 inch)
# 8         13MP + 2MP + 2MP  5MP Front Camera    16.51 cm (6.5 inch)
# 9         13MP + 2MP + 2MP  5MP Front Camera    16.51 cm (6.5 inch)
# 10         8MP Rear Camera  5MP Front Camera    16.51 cm (6.5 inch)
# 11        50MP + 2MP + 2MP  8MP Front Camera    16.51 cm (6.5 inch)
# 12        50MP + 2MP + 2MP  8MP Front Camera    16.51 cm (6.5 inch)
# 13        50MP + 2MP + 2MP  8MP Front Camera    16.51 cm (6.5 inch)
# 14  48MP + 5MP + 2MP + 2MP  8MP Front Camera  16.55 cm (6.515 inch)
# 15        13MP + 2MP + 2MP  5MP Front Camera    16.51 cm (6.5 inch)
# 16  48MP + 5MP + 2MP + 2MP  8MP Front Camera  16.55 cm (6.515 inch)
# 17              13MP + 2MP  5MP Front Camera    15.8 cm (6.22 inch)
# 18              13MP + 2MP  5MP Front Camera    15.8 cm (6.22 inch)
# 19         8MP Rear Camera  5MP Front Camera    16.51 cm (6.5 inch)
# 20         8MP Rear Camera  5MP Front Camera    16.51 cm (6.5 inch)
# 21        50MP + 2MP + 2MP  8MP Front Camera    16.51 cm (6.5 inch)
# 22        50MP + 2MP + 2MP  8MP Front Camera    16.51 cm (6.5 inch)
# 23        50MP + 2MP + 2MP  8MP Front Camera    16.51 cm (6.5 inch)
#
#    Display Resolution              Processor Processor Cores Battery Capacity  \
# 0   1600 x 720 Pixels                SC9863A       Octa Core          76.4 mm
# 1   1600 x 720 Pixels                SC9863A       Octa Core          76.4 mm
# 2   1600 x 720 Pixels                SC9863A       Octa Core          76.4 mm
# 3   1600 x 720 Pixels             Exynos 850       Octa Core         6000 mAh
# 4   1600 x 720 Pixels     MediaTek Helio G85       Octa Core          75.9 mm
# 5   1600 x 720 Pixels     MediaTek Helio G85       Octa Core          75.9 mm
# 6   1600 x 720 Pixels     MediaTek Helio G85       Octa Core          75.9 mm
# 7   1600 x 720 Pixels            Unisoc T610       Octa Core            76 mm
# 8   1600 x 720 Pixels            Unisoc T610       Octa Core            76 mm
# 9   1600 x 720 Pixels            Unisoc T610       Octa Core            76 mm
# 10  1600 x 720 Pixels                SC9863A       Octa Core          76.4 mm
# 11  1600 x 720 Pixels  Unisoc T610 Octa Core       Octa Core            76 mm
# 12  1600 x 720 Pixels  Unisoc T610 Octa Core       Octa Core            76 mm
# 13  1600 x 720 Pixels     MediaTek Helio G85       Octa Core          75.9 mm
# 14  1600 x 720 Pixels             Exynos 850       Octa Core         6000 mAh
# 15  1600 x 720 Pixels            Unisoc T610       Octa Core            76 mm
# 16  1600 x 720 Pixels             Exynos 850       Octa Core         6000 mAh
# 17  1520 x 720 Pixels     MediaTek Helio P35       Octa Core         4230 mAh
# 18  1520 x 720 Pixels     MediaTek Helio P35       Octa Core         4230 mAh
# 19  1600 x 720 Pixels              Octa-core       Octa Core          76.4 mm
# 20  1600 x 720 Pixels              Octa-core       Octa Core          76.4 mm
# 21  1600 x 720 Pixels            Unisoc T618       Octa Core            76 mm
# 22  1600 x 720 Pixels            Unisoc T618       Octa Core            76 mm
# 23  1600 x 720 Pixels            Unisoc T618       Octa Core            76 mm
#
#       Price                                        Product URL
# 0    ₹7,499  https://www.flipkart.com/realme-narzo-50i-carb...
# 1    ₹7,499  https://www.flipkart.com/realme-narzo-50i-mint...
# 2    ₹8,999  https://www.flipkart.com/realme-narzo-50i-carb...
# 3   ₹11,499  https://www.flipkart.com/samsung-galaxy-f12-se...
# 4   ₹12,499  https://www.flipkart.com/realme-narzo-50a-oxyg...
# 5   ₹11,499  https://www.flipkart.com/realme-narzo-50a-oxyg...
# 6   ₹11,499  https://www.flipkart.com/realme-narzo-50a-oxyg...
# 7   ₹10,499  https://www.flipkart.com/realme-c21y-cross-blu...
# 8    ₹9,499  https://www.flipkart.com/realme-c21y-cross-blu...
# 9   ₹10,499  https://www.flipkart.com/realme-c21y-cross-bla...
# 10   ₹8,999  https://www.flipkart.com/realme-narzo-50i-mint...
# 11  ₹11,999  https://www.flipkart.com/realme-c25y-glacier-b...
# 12  ₹11,999  https://www.flipkart.com/realme-c25y-metal-gre...
# 13  ₹12,499  https://www.flipkart.com/realme-narzo-50a-oxyg...
# 14  ₹11,499  https://www.flipkart.com/samsung-galaxy-f12-sk...
# 15   ₹9,499  https://www.flipkart.com/realme-c21y-cross-bla...
# 16  ₹11,499  https://www.flipkart.com/samsung-galaxy-f12-ce...
# 17   ₹9,490  https://www.flipkart.com/oppo-a12-black-32-gb/...
# 18  ₹10,490  https://www.flipkart.com/oppo-a12-flowing-silv...
# 19   ₹7,499  https://www.flipkart.com/realme-c11-2021-cool-...
# 20   ₹7,499  https://www.flipkart.com/realme-c11-2021-cool-...
# 21  ₹10,999  https://www.flipkart.com/realme-c25-y-metal-gr...
# 22  ₹11,999  https://www.flipkart.com/realme-c25-y-metal-gr...
# 23  ₹11,999  https://www.flipkart.com/realme-c25-y-glacier-...

# %%
# Saving the dataframe in csv file
Flipkart.to_csv('Flipkart_smartphone.csv')

# %% [markdown]
# # Question.5

# %%
driver.get('https://www.google.com/maps/')

# %%
#Creating a function to enter the city name 
city = input('Enter City Name : ') 
driver.find_element_by_id('searchboxinput').send_keys(city)
# Out:
# Enter City Name : Bareilly

# %%
# Scraping the entered city latitude and Longitude from google map
lat = driver.current_url.split('/@')[1].split(',')[0]
long = driver.current_url.split('/@')[1].split(',')[1].split(',')[0]
print('Latitude:', lat, 'Longitude:', long)
# Out:
# Latitude: 28.3973819 Longitude: 84.1301498

# %% [markdown]
# # Question.6

# %%
driver.get('https://trak.in/')

# %%
# Entering the details in the search bar
search_button = driver.find_element_by_xpath('//li[@id="menu-item-51510"]/a').get_attribute('href')
driver.get(search_button)

# %%
date = []
for i in driver.find_elements_by_xpath('//td[@class = "column-2"]')[:29]:
    date.append(i.text.replace('/n',''))
    
#performed indexing for each column to fetch the data between January 21 – March 21
date = date[5:]
startup_name = []
for j in driver.find_elements_by_xpath('//td[@class = "column-3"]')[:29]:
    startup_name.append(j.text.replace('/n',''))
startup_name = startup_name[5:]

# %% [markdown]
# Performing indexing for each column to fetch the data between January 21 – March 21

# %%
industry = []
for j in driver.find_elements_by_xpath('//td[@class = "column-4"]')[:29]:
    industry.append(j.text.replace('/n',''))
industry = industry[5:]

# %%
subvertical = []
for j in driver.find_elements_by_xpath('//td[@class = "column-5"]')[:29]:
    subvertical.append(j.text.replace('/n',''))
subvertical = subvertical[5:]

# %%
loc = []
for j in driver.find_elements_by_xpath('//td[@class = "column-6"]')[:29]:
    loc.append(j.text.replace('/n',''))
loc = loc[5:]

investor_name = []
for j in driver.find_elements_by_xpath('//td[@class="column-7"]')[:29]:
    investor_name.append(j.text.replace('/n',''))
investor_name = investor_name[5:]

investment_type = []
for j in driver.find_elements_by_xpath('//td[@class="column-8"]')[:29]:
    investment_type.append(j.text.replace('/n',''))
investment_type = investment_type[5:]

amt = []
for j in driver.find_elements_by_xpath('//td[@class="column-9"]')[:29]:
    amt.append(j.text.replace('/n',''))
amt = amt[5:]

# %%
funding_df = pd.DataFrame({})
funding_df['Date'] = date
funding_df['Startup name'] = startup_name
funding_df['Industry'] = industry
funding_df['Subvertical'] = subvertical
funding_df['Location'] = loc
funding_df['Investor name'] = investor_name
funding_df['Investment tpye'] = investment_type
funding_df['Amount(in USD)'] = amt

funding_df
# Out:
#           Date            Startup name                Industry  \
# 0   04/03/2021               DealShare              E-commerce
# 1   31/03/2021                Uniphore              Technology
# 2   30/03/2021                   Dunzo              E-commerce
# 3   30/03/2021                  BYJU’S                Edu-tech
# 4   23/03/2021             SkilloVilla                Edu-tech
# 5   25/03/2021                CityMall              E-commerce
# 6   26/03/2021                   DotPe                 FinTech
# 7   11/02/2021                Doubtnut                Edu Tech
# 8   22/02/2021                  Zomato             Hospitality
# 9   19/02/2021               Fingerlix             Hospitality
# 10  17/02/2021                   Zolve                 FinTech
# 11  15/02/2021               KreditBee                 Finance
# 12  12/02/2021               Pepperfry              E-commerce
# 13  12/02/2021                 Grofers              E-Commerce
# 14  09/02/2021                 Nothing              Technology
# 15  09/02/2021             SplashLearn                  EdTech
# 16  15/01/2021         Digit Insurance      Financial Services
# 17  28/01/2021  Bombay Shaving Company  Consumer Goods Company
# 18  19/01/2021                  DeHaat        AgriTech Startup
# 19  19/01/2021               Darwinbox                    SaaS
# 20  18/01/2021                   mfine     Health Tech Startup
# 21  18/01/2021                   Udayy                  EdTech
# 22  11/01/2021           True Elements            Food Startup
# 23  13/01/2021                   Saveo          B2B E-commerce
#
#                                           Subvertical           Location  \
# 0                            Online shopping platform  Jaipur, Rajasthan
# 1             Conversational Service Automation (CSA)          Palo Alto
# 2                            Hyper-local delivery app          Bengaluru
# 3                                     Online tutoring          Bengaluru
# 4                 Career and job-oriented upskilling.          Bengaluru
# 5        Social ecommerce and online grocery platform            Gurgaon
# 6   Commerce and payments platform to offline ente...            Gurgaon
# 7                                 E-Learning Platform            Gurgaon
# 8                       Online Food Delivery Platform            Gurgaon
# 9                       Semi-cooked food delivery app             Mumbai
# 10                             Global Neobank Venture             Mumbai
# 11                           Digital lending platform          Bengaluru
# 12                        Multi-brand furniture brand             Mumbai
# 13                                 Online supermarket            Gurgaon
# 14                        Consumer Technology Venture             London
# 15                      Game-based learning programme            Gurgaon
# 16                                 Insurance Services          Bengaluru
# 17      Shave care, beard care, and skincare products          New Delhi
# 18  online marketplace for farm products and services              Patna
# 19                                            HR Tech             Mumbai
# 20                 AI-powered telemedicine mobile app          Bengaluru
# 21     Online learning platform for kids in class 1-5            Gurgaon
# 22                      Whole Food plant based Nashta               Pune
# 23                                         Pharmacies          Bengaluru
#
#                                         Investor name Investment tpye  \
# 0                                     Innoven Capital  Debt Financing
# 1                           Sorenson Capital Partners        Series D
# 2                           Krishtal Advisors Pte Ltd        Series E
# 3          MC Global Edtech, B Capital, Baron, others        Series F
# 4                               Titan Capital, others            Seed
# 5                                      Accel Partners        Series A
# 6                                                PayU        Series A
# 7   SIG Global, Sequoia Capital, WaterBridge Ventu...        Series B
# 8                                  Tiger Global, Kora         Venture
# 9            Rhodium Trust, Accel Partners and Swiggy        Series C
# 10     Accel Partners and Lightspeed Venture Partners            Seed
# 11  Azim Premji’s PremjiInvest and South Korea’s M...        Series C
# 12                                    InnoVen Capital  Debt Financing
# 13                         SoftBank Vision Fund (SVF)     Unspecified
# 14                                                 GV        Series A
# 15                                       Owl Ventures        Series C
# 16   A91 Partners, Faering Capital, TVS Capital Funds         Venture
# 17                                  Reckitt Benckiser         Venture
# 18                                    Prosus Ventures        Series C
# 19                                Salesforce Ventures            Seed
# 20                         Heritas Capital Management   Venture Round
# 21                                    Sequoia Capital    Seed Funding
# 22                              SIDBI Venture Capital          Series
# 23          Matrix Partners India, RTP Global, others            Seed
#
#    Amount(in USD)
# 0     250,000,000
# 1     140,000,000
# 2       8,000,000
# 3     460,000,000
# 4     300,000,000
# 5      11,000,000
# 6      27,500,000
# 7       2,500,000
# 8     250,000,000
# 9    2,747,045.20
# 10    1,50,00,000
# 11     75,000,000
# 12      4,773,958
# 13     55,000,000
# 14     15,000,000
# 15     18,000,000
# 16    1,80,00,000
# 17   6,172,258.50
# 18     30,000,000
# 19     15,000,000
# 20     16,000,000
# 21     15,000,000
# 22    100,000,000
# 23      4,000,000

# %% [markdown]
# # Question.7

# %%
driver.get('https://www.digit.in/')

# %%
#clicking on top 10 tab
top10=driver.find_element_by_xpath("/html/body/div[2]/div/div[4]/ul/li[4]/a")
top10.click()

# %%
#clicking on laptops option
laptop=driver.find_element_by_xpath("/html/body/div[2]/div/div[4]/ul/li[3]/a")
laptop.click()

# %%
#best gaming laptops link
best_gaming=driver.find_element_by_xpath("/html/body/div[7]/div/div[2]/div[2]/ul/li[10]/a")
driver.get(best_gaming.get_attribute('href'))

# %%
#Creating Empty List

Gaming_Laptops = {}
Gaming_Laptops['Laptop_name'] = []
Gaming_Laptops['OS'] = []
Gaming_Laptops['display'] = []
Gaming_Laptops['processor'] = []
Gaming_Laptops['HDD'] = []
Gaming_Laptops['RAM'] = []
Gaming_Laptops['weight'] = []
Gaming_Laptops['dimension'] = []
Gaming_Laptops['GPU'] = []
Gaming_Laptops['price'] = []

time.sleep(1)

# Scraping names
names=driver.find_elements_by_xpath("//div[@class='right-container']/div/a/h3")
for i in names:
    Gaming_Laptops['Laptop_name'].append(i.text)

time.sleep(1)

# Scraping operating system
os=driver.find_elements_by_xpath("//div[@class='product-detail']/div/ul/li[1]/div/div")
for i in os:
    Gaming_Laptops['OS'].append(i.text)

time.sleep(1)

# Scraping display
displays=driver.find_elements_by_xpath("//div[@class='product-detail']/div/ul/li[2]/div/div")
for i in displays:
    Gaming_Laptops['display'].append(i.text)

time.sleep(1)

# Scraping processor
processors=driver.find_elements_by_xpath("//div[@class='value']")
for i in processors:
    Gaming_Laptops['processor'].append(i.text)

time.sleep(1)

# Scraping memory
memories=driver.find_elements_by_xpath("//div[@class='Spcs-details'][1]/table/tbody/tr[6]/td[3]")# extrat HDD and RAM form xpath
for i in memories:
    Gaming_Laptops['HDD'].append(i.text.split("/")[0])
    Gaming_Laptops['RAM'].append(i.text.split("/")[1])

time.sleep(1)

# Scraping weight
weights=driver.find_elements_by_xpath("//div[@class='Spcs-details'][1]/table/tbody/tr[7]/td[3]")# extrat weight form xpath
for i in weights:
    Gaming_Laptops['weight'].append(i.text)

time.sleep(1)

# Scraping dimension
dimension=[]
dimensions=driver.find_elements_by_xpath("//div[@class='Spcs-details'][1]/table/tbody/tr[8]/td[3]") 
for i in dimensions:
    Gaming_Laptops['dimension'].append(i.text)

time.sleep(1)

# Scraping graphical processor
GPUs=driver.find_elements_by_xpath("//div[@class='Spcs-details'][1]/table/tbody/tr[9]/td[3]") 
for i in GPUs:
    Gaming_Laptops['GPU'].append(i.text)

time.sleep(1)

#Scraping price
price=driver.find_elements_by_xpath("//table[@id='summtable']//tr//td[3]")
for i in price:
    Gaming_Laptops['price'].append(i.text)

# %%
Gaming_Laptops['processor'] = Gaming_Laptops['processor'][2:40:4]

# %%
#Make data frame
Gaming_Laptops=pd.DataFrame(Gaming_Laptops)
Gaming_Laptops
# Out:
#                    Laptop_name               OS              display  \
# 0                 ACER NITRO 5       WINDOWS 10  15.6" (1920 X 1080)
# 1              MSI STEALTH 15M       WINDOWS 10  15.6" (1920 X 1080)
# 2       ASUS ROG STRIX SCAR 15       WINDOWS 10  15.6" (2560 X 1440)
# 3        ALIENWARE AREA 51M R2  WINDOWS 10 HOME  17.3" (1920 X 1080)
# 4             ALIENWARE M15 R3  WINDOWS 10 HOME  15.6" (3840 X 2160)
# 5       ASUS ROG STRIX SCAR 15  WINDOWS 10 HOME  15.6" (1920 X 1080)
# 6            ASUS ZEPHYRUS G14  WINDOWS 10 HOME    14" (1920 X 1080)
# 7             LENOVO LEGION 5I   WINDOWS 10 PRO  15.6" (1920 X 1080)
# 8     ASUS ROG ZEPHYRUS DUO 15       WINDOWS 10  15.6" (3840 X 1100)
# 9  ACER ASPIRE 7 GAMING LAPTOP  WINDOWS 10 HOME  15.6" (1920 X 1080)
#
#                                     processor         HDD           RAM  \
# 0             AMD RYZEN 9 OCTA CORE | 2.4 GHZ    1 TB HDD  16 GBGB DDR4
# 1        INTEL CORE I7 11TH GEN - 11375H | NA    1 TB SSD  16 GBGB DDR4
# 2    AMD RYZEN 9 OCTA CORE - 5900HX | 3.3 GHZ    2 TB SSD  32 GBGB DDR4
# 3   10TH GEN INTEL® CORE™ I7-10700 | 2.90 GHZ    1 TB SSD  16 GBGB DDR4
# 4       10TH GEN INTEL® CORE™ I9-10980HK | NA    1 TB SSD  16 GBGB DDR4
# 5               AMD RYZEN™ 9 5900HX | 3.3 GHZ    1 TB SSD  16 GBGB DDR4
# 6               AMD 3RD GEN RYZEN 9 | 3.3 GHZ    1 TB SSD  16 GBGB DDR4
# 7  10TH GEN INTEL® CORE™ I5-10300H | 2.50 GHZ    1 TB SSD  16 GBGB DDR4
# 8          INTEL CORE I7 10TH GEN 10875H | NA  512 GB SSD   4 GBGB DDR4
# 9           AMD RYZEN™ 5-5500U HEXA-CORE | NA  512 GB SSD   8 GBGB DDR4
#
#   weight                dimension                            GPU      price
# 0    2.4       363.4 x 255 x 23.9        NVIDIA GeForce RTX 3070  ₹ 129,990
# 1    1.7      358.3 x 248 x 16.15        NVIDIA GeForce RTX 3060  ₹ 134,990
# 2   2.30         354 x 259 x 22.6        NVIDIA GeForce RTX 3080  ₹ 268,990
# 3    4.1   27.65 x 402.6 x 319.14        Intel® UHD Graphics 630  ₹ 342,989
# 4     NA                       NA                             NA  ₹ 319,990
# 5   2.30       35.4 x 25.9 x 2.26      NVIDIA® GeForce RTX™ 3070  ₹ 215,990
# 6   1.65        32.5 x 22.1 x 1.8        NVIDIA GeForce RTX 2060  ₹ 164,990
# 7    2.3  363.06 x 259.61 x 23.57  NVIDIA® GeForce® GTX 1650 4GB   ₹ 76,988
# 8    2.4  268.30 x 360.00 x 20.90  NVIDIA GeForce RTX 2070 Max-Q  ₹ 185,000
# 9   2.15       2.29 x 36.3 x 25.4      NVIDIA® GeForce® GTX 1650   ₹ 57,900

# %% [markdown]
# # Question.8

# %%
driver.get('https://www.forbes.com')

# %%
# Clicking the explore button
button9 = driver.find_element_by_xpath("//button[@class='icon--hamburger']")
button9.click()

time.sleep(1)

# %%
# Select billioners 
billioners = driver.find_element_by_xpath("/html/body/div[1]/header/nav/div[3]/ul/li[1]")
billioners.click()

time.sleep(1)

# %%
# Select world billioners 
world_billioners= driver.find_element_by_xpath("/html/body/div[1]/header/nav/div[3]/ul/li[1]/div[2]/ul/li[2]/a")
world_billioners.click()

time.sleep(1)

# %%
rank=[]
for i in driver.find_elements_by_xpath('//div[@ class="rank"]'):
    rank.append(i.text.replace('\n',''))
    
len(rank)
# Out:
# 200

# %%
Name=[]
for i in driver.find_elements_by_xpath('//div[@ class="personName"]'):
    Name.append(i.text.replace('\n',''))
    
len(Name)
# Out:
# 200

# %%
Net_worth=[]
for i in driver.find_elements_by_xpath('//div[@ class="netWorth"]'):
    Net_worth.append(i.text.replace('\n',''))
    
len(Net_worth)
# Out:
# 200

# %%
Country=[]
for i in driver.find_elements_by_xpath('//div[@ class="countryOfCitizenship"]'):
    Country.append(i.text.replace('\n',''))
    
len(Country)
# Out:
# 200

# %%
source=[]
for i in driver.find_elements_by_xpath('//div[@ class="source-column"]'):
    source.append(i.text.replace('\n',''))

len(source)
# Out:
# 200

# %%
Industry=[]
for i in driver.find_elements_by_xpath('//div[@ class="category"]'):
    Industry.append(i.text.replace('\n',''))
    
len(Industry)
# Out:
# 200

# %%
Age=[]
for i in driver.find_elements_by_xpath('//div[@ class="age"]'):
    Age.append(i.text.replace('\n',''))
    
len(Age)
# Out:
# 200

# %%
for _ in range(13):
    next = driver.find_element_by_xpath('//button[@class="pagination-btn pagination-btn--next "]')
    next.click()
    for i in driver.find_elements_by_xpath('//div[@ class="rank"]'):
        rank.append(i.text.replace('\n',''))
    for i in driver.find_elements_by_xpath('//div[@ class="personName"]'):
        Name.append(i.text.replace('\n',''))
    for i in driver.find_elements_by_xpath('//div[@ class="netWorth"]'):
        Net_worth.append(i.text.replace('\n',''))
    for i in driver.find_elements_by_xpath('//div[@ class="countryOfCitizenship"]'):
        Country.append(i.text.replace('\n',''))
    for i in driver.find_elements_by_xpath('//div[@ class="source-column"]'):
        source.append(i.text.replace('\n',''))
    for i in driver.find_elements_by_xpath('//div[@ class="category"]'):
        Industry.append(i.text.replace('\n',''))
    for i in driver.find_elements_by_xpath('//div[@ class="age"]'):
        Age.append(i.text.replace('\n',''))

# %%
print(len(rank),len(Name),len(Net_worth),len(Country),len(source),len(Industry),len(Age))
# Out:
# 2755 2755 2755 2755 2755 2755 2755

# %%
Billiniore=pd.DataFrame({})

Billiniore['Rank']=rank
Billiniore['Name']=Name
Billiniore['Net_worth']=Net_worth
Billiniore['Industry']=Industry
Billiniore['Source']=source
Billiniore['Citizenship']=Country
Billiniore['Age']=Age

Billiniore
# Out:
#        Rank                      Name Net_worth Industry         Source  \
# 0        1.                Jeff Bezos    $177 B                  Amazon
# 1        2.                 Elon Musk    $151 B           Tesla, SpaceX
# 2        3.  Bernard Arnault & family    $150 B                    LVMH
# 3        4.                Bill Gates    $124 B               Microsoft
# 4        5.           Mark Zuckerberg     $97 B                Facebook
# ...     ...                       ...       ...      ...            ...
# 2750  2674.         Daniel Yong Zhang      $1 B              e-commerce
# 2751  2674.             Zhang Yuqiang      $1 B              Fiberglass
# 2752  2674.             Zhao Meiguang      $1 B             gold mining
# 2753  2674.            Zhong Naixiong      $1 B            conglomerate
# 2754  2674.           Zhou Wei family      $1 B                Software
#
#         Citizenship Age
# 0     United States
# 1     United States
# 2            France
# 3     United States
# 4     United States
# ...             ...  ..
# 2750          China
# 2751          China
# 2752          China
# 2753          China
# 2754          China
#
# [2755 rows x 7 columns]

# %% [markdown]
# # Question.9

# %%
driver.get('https://www.youtube.com/')

# %%
#lets click on a video
clk_video = driver.find_element_by_xpath("//a[@id='video-title-link']").click()
time.sleep(8)

# %%
# scrolling down to get the comments
for i in range(2000):
    driver.execute_script("window.scrollBy(0,1000)")

# fetching required data
comments = []
upvotes = []
times = []
try:
    comment = driver.find_elements_by_xpath("//yt-formatted-string[@class='style-scope ytd-comment-renderer']")
    for i in comment:
        comments.append(i.text)
except NoSuchElementException:
    comments.append('-')
time.sleep(3)

# fetching upvotes
try:
    up = driver.find_elements_by_xpath("//span[@class='style-scope ytd-comment-action-buttons-renderer']")
    for i in up:
        upvotes.append(i.text)
except NoSuchElementException:
    comments.append('-')
    time.sleep(3)

# fetching time when comment was posted
try:
    tim = driver.find_elements_by_xpath("//a[@class='yt-simple-endpoint style-scope yt-formatted-string']")
    for i in tim:
        times.append(i.text.replace('(edited)',''))
except NoSuchElementException:
    times.append('-')
time.sleep(3)

# %%
print(len(comments),len(times),len(upvotes))
# Out:
# 800 900 840

# %%
#Creating dataframe for scraped data

Youtube=pd.DataFrame({})
Youtube['Comments'] = comments[:500]
Youtube['Comment_time'] = times[:500]
Youtube['Comment upvotes'] = upvotes[:500]

Youtube
# Out:
#                                               Comments   Comment_time  \
# 0
# 1                       Here after iPhone 13 trailer 😂
# 2
# 3    I salute to this amazing women's struggle and ...
# 4
# ..                                                 ...            ...
# 495  This is the kind of song they sing and they ex...    3 years ago
# 496
# 497                                       Just perfect  11 months ago
# 498
# 499  Lyrics : Dum maro dum\nDidi ne kuch jyada hi s...     1 year ago
#
#     Comment upvotes
# 0
# 1                3K
# 2
# 3               678
# 4
# ..              ...
# 495               1
# 496
# 497               2
# 498
# 499               7
#
# [500 rows x 3 columns]

# %% [markdown]
# # Question.10

# %%
driver.get('https://www.hostelworld.com/')

# %%
# Locating the location search bar
search_bar = driver.find_element_by_xpath("//input[@class='location-text']")
search_bar.click()

# %%
# Entering Lonodn in search bar
search_bar.send_keys('london')
time.sleep(2)

# %%
# Selecting london from pop-ups
london = driver.find_elements_by_xpath("//div[@class='label']")
london[0].click()
time.sleep(3)

# %%
# Do click on search button
search_but = driver.find_element_by_xpath("//button[@id='search-button']")
search_but.click()
time.sleep(5)

# %%
#lets find required data
hostel_name = []
distance = []
pvt_prices = []
dorms_price = []
rating = []
reviews = []
over_all = []
facilities = []
description =[]
product_url = []

# %%
# Scraping the required informations
for i in driver.find_elements_by_xpath("//div[@class = 'pagination-item pagination-current' or @class='pagination-item']"):
    i.click()
    time.sleep(4)
    
# Scraping hostel name
    try:
        name = driver.find_elements_by_xpath("//h2[@class='title title-6']")
        for i in name:
            hostel_name.append(i.text)
    except NoSuchElementException:
        hostel_name.append('-')
        
# Scraping distance from city centre
    try:
        dist = driver.find_elements_by_xpath("//div[@class='subtitle body-3']//a//span[1]")
        for i in dist:
            distance.append(i.text.replace('Hostel - ',''))
    except NoSuchElementException:
        distance.append('-')
        
    for i in driver.find_elements_by_xpath("//div[@class='prices-col']"):
# Scraping privates from price
        try:
            pvt_price = driver.find_element_by_xpath("//a[@class='prices']//div[1]//div")
            pvt_prices.append(pvt_price.text)
        except NoSuchElementException:
            pvt_prices.append('-')
            
# Scraping dorms from price
    for i in driver.find_elements_by_xpath("//div[@class='prices-col']"):
        try:
            dorms = driver.find_element_by_xpath("//a[@class='prices']//div[2]//div")
            dorms_price.append(dorms.text)
        except NoSuchElementException:
            dorms_price.append('-')
            
# Scraping facilities
    try:
        fac1 = driver.find_elements_by_xpath("//div[@class='has-wifi']")
        fac2 = driver.find_elements_by_xpath("//div[@class='has-sanitation']")
        for i in fac1:
            for j in fac2:
                facilities.append(i.text +', '+ j.text )
    except NoSuchElementException:
        facilities.append('-')
        
# Fetching url of each hostel
    p_url = driver.find_elements_by_xpath("//div[@class='prices-col']//a[2]")
    for i in p_url:
        product_url.append(i.get_attribute('href'))

for i in product_url:
    driver.get(i)
    time.sleep(3)
# Do click on show more button for description
    try:
        driver.find_element_by_xpath("//a[@class='toggle-content']").click()
        time.sleep(5)
    except NoSuchElementException:
        pass
    
# Scraping ratings
    try:
        rat = driver.find_element_by_xpath("//div[@class='score orange big' or @class='score gray big']")
        rating.append(rat.text)
    except NoSuchElementException:
        rating.append('-')
        
# Scraping total reviews   
    try:
        rws = driver.find_element_by_xpath("//div[@class='reviews']")
        reviews.append(rws.text.replace('Total Reviews',''))
    except NoSuchElementException:
        reviews.append('-')
        
# Fetching overall review
    try:
        overall_rw = driver.find_element_by_xpath("//div[@class='keyword']//span")
        over_all.append(overall_rw.text)
    except NoSuchElementException:
        over_all.append('-')
        
# Fetching property description 
    try:
        disc = driver.find_element_by_xpath("//div[@class='content']")
        description.append(disc.text)
    except NoSuchElementException:
        over_all.append('-')

# %%
# Creating dataframe to store scraped data

Hostels = pd.DataFrame({})
Hostels['Hostel_Name'] = hostel_name[:70]
Hostels['Distance fron city centre'] = distance[:70]
Hostels['Ratings'] = rating[:70]
Hostels['Total_reviews'] = reviews[:70]
Hostels['Overall Reviews'] = over_all[:70]
Hostels['Privates from price'] = pvt_prices[:70]
Hostels['Dorms from price'] = dorms_price[:70]
Hostels['Facilities'] = facilities[:70]
Hostels['Description'] = description[:70]

Hostels
# Out:
#                                Hostel_Name  \
# 0                        Mornington Camden
# 1              Smart Russell Square Hostel
# 2                  Smart Camden Inn Hostel
# 3                            Selina Camden
# 4                  Queen Elizabeth Chelsea
# ..                                     ...
# 65  Best Western Boltons London Kensington
# 66           Airways Hotel Victoria London
# 67                           Elmwood Hotel
# 68                   Hyde Park Court Hotel
# 69                Budget London Apartments
#
#              Distance fron city centre Ratings Total_reviews Overall Reviews  \
# 0               4.1km from city centre     8.3           44         Fabulous
# 1               2.6km from city centre     6.7         9567             Good
# 2               4.4km from city centre     8.5         2738         Fabulous
# 3               5.5km from city centre     9.1           14           Superb
# 4               5.7km from city centre     7.5         3212        Very Good
# ..                                 ...     ...           ...             ...
# 65      Hotel - 5.4km from city centre     2.0            2           Rating
# 66      Hotel - 2.1km from city centre     6.9           46             Good
# 67      Hotel - 3.2km from city centre     6.3          113             Good
# 68      Hotel - 4.3km from city centre       -            0        No Rating
# 69  Apartment - 8.2km from city centre     2.0          356           Rating
#
#    Privates from price Dorms from price  \
# 0              NPR5475          NPR5297
# 1              NPR5475          NPR5297
# 2              NPR5475          NPR5297
# 3              NPR5475          NPR5297
# 4              NPR5475          NPR5297
# ..                 ...              ...
# 65             NPR7087          NPR4004
# 66             NPR7087          NPR4004
# 67             NPR7087          NPR4004
# 68             NPR7087          NPR4004
# 69             NPR7087          NPR4004
#
#                                          Facilities  \
# 0   Free WiFi, Follows Covid-19 sanitation guidance
# 1   Free WiFi, Follows Covid-19 sanitation guidance
# 2   Free WiFi, Follows Covid-19 sanitation guidance
# 3   Free WiFi, Follows Covid-19 sanitation guidance
# 4   Free WiFi, Follows Covid-19 sanitation guidance
# ..                                              ...
# 65  Free WiFi, Follows Covid-19 sanitation guidance
# 66  Free WiFi, Follows Covid-19 sanitation guidance
# 67  Free WiFi, Follows Covid-19 sanitation guidance
# 68  Free WiFi, Follows Covid-19 sanitation guidance
# 69  Free WiFi, Follows Covid-19 sanitation guidance
#
#                                           Description
# 0                   2 Hurdwick Place, London, England
# 1                 71 Guilford Street, London, England
# 2        55/57 Bayham Street, Camden, London, England
# 3       89 Chalk Farm Rd, Chalk Farm, London, England
# 4                    58 Bagleys Lane, London, England
# ..                                                ...
# 65               19-21 Penywern Road, London, England
# 66    29 St. Georges Drive, Victoria, London, England
# 67     19 & 20 Argyle square, London, London, England
# 68                 48 Norfolk Square, London, England
# 69  30 Chatsworth Rd., Willesden Green, London, En...
#
# [70 rows x 9 columns]
